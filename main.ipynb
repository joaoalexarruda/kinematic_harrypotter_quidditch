# %%
import sympy as sy
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math, Image, YouTubeVideo
import sympy.physics.mechanics as me
from sympy.physics.vector.printing import vlatex

# %% [markdown]
# # Análise cinemática de uma partida de Quadribol

# %%
vid = YouTubeVideo("fP5UM4elIes", width=720, height=480)
display(vid)

# %% [markdown]
# Neste trabalho, buscou-se fazer uma análise cinemática de um trecho do filme Harry Potter e a Pedra Filosofal. No universo bruxo, o esporte mais aclamado de todos chama-se Quadribol. Desconsideraremos todas as regras e focaremos na cena em que Harry captura o Pomo de Ouro pela primeira vez.

# %%
vid2 = YouTubeVideo("F3FPSYcUY48", width=720, height=480, start=100)
display(vid2)
